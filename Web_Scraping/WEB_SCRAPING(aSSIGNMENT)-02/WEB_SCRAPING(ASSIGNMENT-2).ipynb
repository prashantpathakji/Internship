# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\prashant pathak\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\prashant pathak\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\prashant pathak\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\prashant pathak\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\prashant pathak\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: outcome in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: idna in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: pycparser in c:\users\prashant pathak\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\prashant pathak\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\prashant pathak\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\prashant pathak\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Prashant Pathak\Downloads\chromedriver_win32\chormedriver.exe")

# %%
driver.maximize_window()

# %%
driver=webdriver.Chrome('chormedriver.exe')

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.

# %%
url='https://www.naukri.com/'
driver.get(url)

search_job=driver.find_element(By.CLASS_NAME,"suggestor-input")
search_job.send_keys("Data Analyst")

search_locn=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_locn.send_keys("Bangalore")

search_btn=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search_btn.click()

job_titles=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags:
    job_titles.append(i.text)
    
company_name=[]
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags:
    company_name.append(i.text)
    
exp=[]
exp_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 expwdth']")
for i in exp_tags:
    exp.append(i.text)
    
loc=[]
loc_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 locWdth']")
for i in loc_tags:
    loc.append(i.text)
    
jobs=pd.DataFrame({"Job Title":job_titles,"Company":company_name,"Experiance":exp,"Location":loc})
print(len(job_titles),len(company_name),len(exp),len(loc))
job=jobs[0:10]
job
# Out:
# 20 20 20 20
#                                            Job Title  \
# 0                                       Data Analyst
# 1  APRP Manager / Senior Data Analyst - MeritTrac...
# 2                                    Sr Data Analyst
# 3                     Senior Data Management Analyst
# 4           Senior Data Analyst - PLM Data Migration
# 5                                People Data Analyst
# 6       Associate Healthcare Research & Data Analyst
# 7                                  Lead Data Analyst
# 8  Contractual Hiring For Top MNC || Business Dat...
# 9            Master Data Management Business Analyst
#
#                               Company Experiance             Location
# 0                             Cargill    3-5 Yrs  Bangalore/Bengaluru
# 1                           MeritTrac   9-14 Yrs  Bangalore/Bengaluru
# 2  Inspira Enterprise India Pvt. Ltd.    3-4 Yrs  Bangalore/Bengaluru
# 3                         Wells Fargo    5-7 Yrs  Bangalore/Bengaluru
# 4                                 CGI    3-6 Yrs  Bangalore/Bengaluru
# 5                     Western Digital    6-8 Yrs  Bangalore/Bengaluru
# 6                           Clarivate    3-4 Yrs  Bangalore/Bengaluru
# 7         Mobile Premier League (MPL)    4-7 Yrs  Bangalore/Bengaluru
# 8                           TeamLease    5-8 Yrs  Bangalore/Bengaluru
# 9                           Accenture    6-8 Yrs  Bangalore/Bengaluru

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
url='https://www.naukri.com/'
driver.get(url)

search_job=driver.find_element(By.CLASS_NAME,"suggestor-input")
search_job.send_keys("Data Scientist")

search_locn=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
search_locn.send_keys("Bangalore")

search_btn=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search_btn.click()

job_titles=[]
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags:
    job_titles.append(i.text)
    
company_name=[]
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags:
    company_name.append(i.text)
    
exp=[]
exp_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 expwdth']")
for i in exp_tags:
    exp.append(i.text)
    
loc=[]
loc_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis fleft fs12 lh16 locWdth']")
for i in loc_tags:
    loc.append(i.text)
    
print(len(job_titles),len(company_name),len(exp),len(loc))

jobs=pd.DataFrame({"Job Title":job_titles,"Company":company_name,"Experiance":exp,"Location":loc})
job=jobs[0:10]
job
# Out:
# 20 20 20 20
#                                         Job Title                  Company  \
# 0                Analystics & Modeling Specialist                Accenture
# 1                Assistant Manager - Data Science               Citiustech
# 2                           Senior Data Scientist                    Wipro
# 3                      Program Manager, Analytics                     Uber
# 4  Data Scientist - Looking For Immediate Joiners                    Wipro
# 5                                  Data Scientist                   Altair
# 6                           Senior Data Scientist  Boston Consulting Group
# 7                             Data Scientist - II                  Bizongo
# 8                               Lead ML Scientist        Fractal Analytics
# 9                           Senior Data Scientist             Baker Hughes
#
#   Experiance                                           Location
# 0    6-8 Yrs  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1    5-9 Yrs         Hybrid - Bangalore/Bengaluru, Mumbai, Pune
# 2   6-11 Yrs        Hybrid - Bangalore/Bengaluru, Pune, Chennai
# 3    3-7 Yrs                                Bangalore/Bengaluru
# 4   5-10 Yrs  Hybrid - Bangalore/Bengaluru, Hyderabad/Secund...
# 5    2-7 Yrs  Bangalore/Bengaluru, Hyderabad/Secunderabad, P...
# 6   5-10 Yrs    Bangalore/Bengaluru, Mumbai, New Delhi, Chennai
# 7    3-6 Yrs     Bangalore/Bengaluru, India, Mumbai (All Areas)
# 8   6-10 Yrs                        Bangalore/Bengaluru, Mumbai
# 9    6-8 Yrs                        Bangalore/Bengaluru, Mumbai
